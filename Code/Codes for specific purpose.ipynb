# %% [markdown]
# # Finding Outliers

# %%
import statistics
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('Outlier.csv')

# %%
df.head()
# Out:
#    Salary
# 0     500
# 1     600
# 2    1500
# 3     550
# 4     700

# %%
def find_outliers(data):
    anomalies = []

    random_data_std=statistics.stdev(data)
    random_data_mean=statistics.mean(data)
    anomaly_cutoff=random_data_std * 3
    lower_limit=random_data_mean - anomaly_cutoff
    upper_limit=random_data_mean + anomaly_cutoff

    for outlier in data:
        if (outlier > upper_limit) or (outlier < lower_limit):
            anomalies.append(outlier)
    return anomalies

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Salary  8 non-null      int64
# dtypes: int64(1)
# memory usage: 196.0 bytes

# %%
outlier=find_outliers(df['Salary'])

# %%
print(outlier)
# Out:
# []

# %%
plt.boxplot(df)
plt.show()

# %%
df['Salary'].skew()
# Out:
# 1.2249147451895397

# %%
sns.kdeplot(df['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
df['Transformed']=np.log(df['Salary'])

# %%
sns.kdeplot(df['Transformed'])
# Out:
# <Axes: xlabel='Transformed', ylabel='Density'>

# %%
df['Transformed'].skew()
# Out:
# -1.6540904794450322
